# %%
import Compare_pose as i2v

# %% [markdown]
# ## l2_normalize

# %%
i2v.l2_normalize("./video/result/alphapose-TKD_test.json")
i2v.l2_normalize("./video/result/alphapose-TKD_slow.json")
# Out:
# Write l2_norm keypoints
# Write l2_norm keypoints

# %% [markdown]
# ## cos_sim

# %%
#cos_sim(label_json, input_json, label_img, input_video)
Score = i2v.cos_sim("./image/result/alphapose-TKD_1_l2norm.json","./video/result/alphapose-TKD_slow_l2norm.json", "./image/TKD/TKD_1.png", './video/TKD_slow.mp4')
# Score = i2v.cos_sim("./image/result/alphapose-TKD_2_l2norm.json","./video/result/alphapose-TKD_slow_l2norm.json", "./image/TKD/TKD_2.png", './video/TKD_slow.mp4')
# Score = i2v.cos_sim("./image/result/alphapose-TKD_3_l2norm.json","./video/result/alphapose-TKD_slow_l2norm.json", "./image/TKD/TKD_3.png", './video/TKD_slow.mp4')
# Score = i2v.cos_sim("./image/result/alphapose-TKD_4_l2norm.json","./video/result/alphapose-TKD_test_l2norm.json", "./image/TKD/TKD_4.png", './video/TKD_test.mp4')
# Score = i2v.cos_sim("./image/result/alphapose-TKD_5_l2norm.json","./video/result/alphapose-TKD_test_l2norm.json", "./image/TKD/TKD_5.png", './video/TKD_test.mp4')
# Score = i2v.cos_sim("./image/result/alphapose-TKD_6_l2norm.json","./video/result/alphapose-TKD_test_l2norm.json", "./image/TKD/TKD_6.png", './video/TKD_test.mp4')
# Out:
# Frame_Num  :  455
#
# Total_Score  :  97.77946351842424
#
# Head  :  96.69356159651178
#
# LShoulder  :  99.76489656613384
#
# RShoulder  :  99.46023661852831
#
# LElbow  :  95.44245991551014
#
# RElbow  :  99.97146879904817
#
# LWrist  :  91.88070402859438
#
# RWrist  :  92.31852611389064
#
# LHip  :  99.03752986583572
#
# RHip  :  98.62595252627516
#
# LKnee  :  94.8358662005002
#
# Rknee  :  98.82053001646132
#
# LAnkle  :  95.07997595114543
#
# RAnkle  :  97.45320125750719

# %% [markdown]
# ## weightmatch

# %%
Score = i2v.weightmatch("data/image/result/alphapose-TKD_6_l2norm.json","data/video/result/alphapose-TKD_test_l2norm.json", "data/image/TKD/TKD_6.png", 'data/video/TKD_test.mp4')
# Out:
# Frame_Num  :  86
#
# Total_Score  :  98.6466811413887
#
# Head  :  92.07704822954732
#
# LShoulder  :  95.70510772089882
#
# RShoulder  :  91.59218999010258
#
# LElbow  :  97.484091867106
#
# RElbow  :  92.24860262946176
#
# LWrist  :  94.69985241651607
#
# RWrist  :  89.85601000588478
#
# LHip  :  97.6707780342315
#
# RHip  :  98.69188402601108
#
# LKnee  :  97.71715439983255
#
# Rknee  :  92.29289443918638
#
# LAnkle  :  97.89408040603819
#
# RAnkle  :  99.34354862874746

# %% [markdown]
# ## l2_weightmatch

# %%
Score = i2v.l2_weightmatch("data/image/result/alphapose-TKD_6_l2norm.json","data/video/result/alphapose-TKD_test_l2norm.json", "data/image/TKD/TKD_6.png", 'data/video/TKD_test.mp4')
# Out:
# Frame_Num  :  86
#
# Total_Score  :  98.32576891898974
#
# Head  :  91.91311586573003
#
# LShoulder  :  94.80594142727868
#
# RShoulder  :  91.58384676863064
#
# LElbow  :  97.43191080988552
#
# RElbow  :  92.02672640761246
#
# LWrist  :  94.06103482928741
#
# RWrist  :  89.71560774044983
#
# LHip  :  97.53913321988865
#
# RHip  :  98.48273094319582
#
# LKnee  :  97.34138152172225
#
# Rknee  :  90.99894264344199
#
# LAnkle  :  97.8940671497391
#
# RAnkle  :  99.18046028318984

# %%
Score = i2v.dtw_compare("data/video/result/alphapose-TKD_test_l2norm.json","data/video/result/alphapose-TKD_slow_l2norm.json")
# Out:
# Total_Score  :  77.37550829057717
#
# Head  :  89.72904663102801
#
# LShoulder  :  87.60621051067187
#
# RShoulder  :  80.81483027443032
#
# LElbow  :  79.08505507399255
#
# RElbow  :  72.38327974894764
#
# LWrist  :  70.56455711216584
#
# RWrist  :  68.0190577624948
#
# LHip  :  85.52305865664701
#
# RHip  :  80.34990082125356
#
# LKnee  :  68.6928767227993
#
# Rknee  :  62.852528355242676
#
# LAnkle  :  54.924952139719984
#
# RAnkle  :  55.92210060630653
